# %%
import pandas as pd1
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('../data/nascar/503/dk/csv/extracted.csv')

# %%
df
# Out:
#     player_id                 name  salary  projection    floor  ceiling  \
# 0          81          Kyle Larson   11500       42.61  10.6525    172.2
# 1          14         Denny Hamlin   11000       45.16  11.2900    108.9
# 2          86          Ryan Blaney   10700       46.22  11.5550     97.9
# 3         176     Christopher Bell   10200       36.19   9.0475    101.7
# 4         183        Chase Briscoe   10000       46.80  11.7000     99.9
# 5         155        William Byron    9800       30.64   7.6600    121.2
# 6         102        Chase Elliott    9500       38.50   9.6250    112.8
# 7          44          Joey Logano    9200       40.33  10.0825     92.6
# 8         145        Bubba Wallace    9000       40.50  10.1250     65.6
# 9         201             Ty Gibbs    8700       29.74   7.4350     49.3
# 10        166        Tyler Reddick    8500       33.80   8.4500     71.6
# 11        144        Ross Chastain    8300       30.82   7.7050     77.9
# ...

# %%
df.updated_ownership.hist(bins=40)
# Out:
# <Axes: >

# %%
pd.read_csv('../data/nascar/503/dk/lineups/lineups_503_gpp.csv')
# Out:
#     lineup_id  position      player_name  salary  projection  ownership  \
# 0           1         1    William Byron    9800   31.994288       19.4
# 1           1         2    Chase Elliott    9500   40.070800        6.7
# 2           1         3        Cody Ware    4700   17.400000        0.6
# 3           1         4      Joey Logano    9200   41.570147       10.1
# 4           1         5  Brad Keselowski    7800   39.341194       40.3
# 5           1         6       Kyle Busch    8000   38.098696       56.6
# 6           2         1     Denny Hamlin   11000   47.083816        6.5
# 7           2         2      Ryan Blaney   10700   51.993978       58.7
# 8           2         3      Alex Bowman    8100   30.105802        5.7
# 9           2         4        Cody Ware    4700   17.400000        0.6
# 10          2         5        Ty Dillon    4800   23.960000        4.2
# 11          2         6    Chase Briscoe   10000   48.559680       43.1
# ...

# %%
df = pd.read_csv('../data/mma/466/dk/csv/extracted.csv')

# %%
df[['name', 'floor', 'updated_floor', 'projection', 'updated_projection', 'ceiling', 'updated_ceiling']]
# Out:
#                    name  floor  updated_floor  projection  updated_projection  \
# 0          Jared Gordon  34.17      40.660256       88.55           94.985938
# 1              Rob Font  36.17      41.904675       68.62           73.694120
# 2           Rafa Garcia  33.09      31.966996       46.91           43.868807
# 3         Zachary Reese  11.50      13.049866       87.71           89.378651
# 4         Alice Pereira   0.00       0.000000       71.54           71.540000
# 5            Jean Silva  79.81      65.201193       86.87           81.501492
# 6       Claudio Puelles  28.56      31.790144       63.57           63.688394
# 7              Quang Le  18.23      20.577029       57.47           61.849074
# 8       Dusko Todorovic   1.73       2.015939       93.48           97.436567
# 9         Joaquim Silva  11.53      12.428010       62.22           62.427815
# 10         Amanda Lemos  26.93      26.947741       36.70           36.720185
# ...

# %%
df.salary_ownership.describe()
# Out:
# count    28.000000
# mean     17.901786
# std      12.080753
# min       4.785714
# 25%       8.544643
# 50%      11.285714
# 75%      26.467857
# max      53.035714
# Name: salary_ownership, dtype: float64

# %%
df.salary_ownership.hist(bins=30)
# Out:
# <Axes: >

# %%
df[df.name=='Tatiana Suarez']
# Out:
#     player_id            name  salary  projection  floor  ceiling  ownership  \
# 15        552  Tatiana Suarez    9400        99.3   66.1   135.02       51.5
#
#     std_dev  hteam  oteam  htid  otid  agg_proj  confidence  \
# 15     25.0  LEMOS  LEMOS   276   276     93.22        55.0
#
#                game_info  opp_rank  stars  alert_score  ml_odds  win_pct  \
# 15  SUAREZ@LEMOS 1:40 PM        49    3.5            1   -490.0     83.1
#
#     itd_odds opponent  opponent_ml_odds newsletter_signal  \
# 15     135.0      NaN               0.0           neutral
#
#     newsletter_confidence newsletter_reason  ownership_delta  ceiling_delta  \
# 15                    0.5               NaN              0.0            0.0
#
#     strikes_per_fight  strikes_per_min  strike_accuracy  control_per_fight  \
# 15               40.4             2.93             59.8              418.6
#
#     takedowns_per_fight  avg_rounds  last5_win_pct  last5_fppg  \
# ...

# %%
df[df.name=='Amanda Lemos']
# Out:
#     player_id          name  salary  projection  floor  ceiling  ownership  \
# 10        276  Amanda Lemos    6800        36.7  26.93   102.44       10.0
#
#     std_dev  hteam   oteam  htid  otid  agg_proj  confidence  \
# 10     25.0  LEMOS  SUAREZ   276   552     36.77        71.0
#
#                game_info  opp_rank  stars  alert_score  ml_odds  win_pct  \
# 10  SUAREZ@LEMOS 1:40 PM         8    1.5           -3    355.0     22.0
#
#     itd_odds opponent  opponent_ml_odds newsletter_signal  \
# 10     135.0      NaN               0.0           neutral
#
#     newsletter_confidence newsletter_reason  ownership_delta  ceiling_delta  \
# 10                    0.5               NaN              0.0            0.0
#
#     strikes_per_fight  strikes_per_min  strike_accuracy  control_per_fight  \
# 10               21.6             1.43             47.8              198.2
#
#     takedowns_per_fight  avg_rounds  last5_win_pct  last5_fppg  \
# ...

# %%
df
# Out:
#     player_id                 name  salary  projection  floor  ceiling  \
# 0         322         Jared Gordon    9100       88.55  34.17   118.57
# 1         309             Rob Font    8500       68.62  36.17   119.06
# 2        1451          Rafa Garcia    7100       46.91  33.09   101.45
# 3        1748        Zachary Reese    8900       87.71  11.50   112.53
# 4        1920        Alice Pereira    8600       71.54   0.00    85.85
# 5        1754           Jean Silva    9200       86.87  79.81   114.06
# 6         449      Claudio Puelles    8200       63.57  28.56    95.99
# 7        1816             Quang Le    7900       57.47  18.23    93.47
# 8        1302      Dusko Todorovic    9300       93.48   1.73    98.66
# 9         505        Joaquim Silva    8000       62.22  11.53    81.40
# 10        276         Amanda Lemos    6800       36.70  26.93   102.44
# 11       1919          Alden Coria    6700       40.88   0.00    49.06
# ...

# %%
lineups = pd.read_csv('../data/mma/466/dk/lineups/lineups_466_gpp.csv')

# %%
2, lineups.player_name.value_counts()
# Out:
# (2,
#  player_name
#  Rob Font               2
#  Alessandro Costa       2
#  Alexander Hernandez    2
#  Quang Le               2
#  Amanda Lemos           2
#  Rafa Garcia            2
#  Diego Lopes            1
#  Jean Silva             1
#  Jesus Aguilar          1
#  Dustin Stoltzfus       1
#  Jared Gordon           1
#  Zachary Reese          1
#  Tatiana Suarez         1
#  Diego Ferreira         1
#  Claudio Puelles        1
#  Montse Rendon          1
#  Daniil Donchenko       1
#  Dusko Todorovic        1
#  Name: count, dtype: int64)

# %%
lineups
# Out:
#     lineup_id  position          player_name  salary  projection  ownership  \
# 0           1         1          Diego Lopes    7000   48.000028  10.964286
# 1           1         2             Rob Font    8500   73.694120  11.285714
# 2           1         3     Dustin Stoltzfus    7200   46.285238  10.107143
# 3           1         4     Alessandro Costa    9500  108.522010  16.200000
# 4           1         5             Quang Le    7900   61.849074   6.857143
# 5           1         6           Jean Silva    9200   81.501492  11.285714
# 6           2         1          Rafa Garcia    7100   43.868807   4.785714
# 7           2         2        Jesus Aguilar    7500   50.048597   8.571429
# 8           2         3         Amanda Lemos    6800   36.720185   6.321429
# 9           2         4         Jared Gordon    9100   94.985938  21.364286
# 10          2         5        Zachary Reese    8900   89.378651  34.321429
# ...
